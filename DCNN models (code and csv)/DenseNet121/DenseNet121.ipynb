# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane61.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane24.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane85.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane18.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane83.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane93.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane58.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane13.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane28.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane49.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane11.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane14.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane40.jpeg
# /kaggle/input/landusa/UCMerc_LandU/Train/airplane/airplane09.jpeg
# ...

# %%
from keras.applications.densenet import DenseNet121
from tensorflow.keras.layers import GlobalAveragePooling2D , Reshape
from tensorflow.keras.models import Model

# %%
base_model = DenseNet121(weights='imagenet' , include_top = True)
# Out:
# ...
# 33188688/33188688 [==============================] - 0s 0us/step

# %%
base_model.summary()
# Out:
# Model: "densenet121"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0          ['input_1[0][0]']
#
#  conv1/conv (Conv2D)            (None, 112, 112, 64  9408        ['zero_padding2d[0][0]']
#                                 )
#
#  conv1/bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1/conv[0][0]']
#                                 )
#
#  conv1/relu (Activation)        (None, 112, 112, 64  0           ['conv1/bn[0][0]']
#                                 )
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['conv1/relu[0][0]']
#  D)                             )
#
#  pool1 (MaxPooling2D)           (None, 56, 56, 64)   0           ['zero_padding2d_1[0][0]']
# ...

# %%
x = base_model.layers[-2].output

# %%
x = Reshape((1,1,1024))(x)

# %%
x = GlobalAveragePooling2D()(x)

# %%
model = Model(inputs=base_model.input , outputs=x)

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import os
import numpy as np
import pandas as pd

# %%
def extraction(filename , label):
    img = image.load_img(filename, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    features = model.predict(x)
    features = features.tolist()
    features = features[0]
    features.append(label)
    return features

# %%
categories = os.listdir("/kaggle/input/landusa/UCMerc_LandU/Train")
array = []

for folder in categories:
    print("label:",folder)
    for file in os.listdir(f"/kaggle/input/landusa/UCMerc_LandU/Train/{folder}"):
        filepath = f"/kaggle/input/landusa/UCMerc_LandU/Train/{folder}/{file}"            
        array.append(extraction(filepath,folder))


df = pd.DataFrame(array)
df.to_excel(f'/kaggle/working/densenet1024.xlsx', index=False)
# Out:
# label: airplane
# ...
# 1/1 [==============================] - 0s 32ms/step
# label: tenniscourt
# ...
# 1/1 [==============================] - 0s 33ms/step
# label: river
# ...
# 1/1 [==============================] - 0s 55ms/step
# label: denseresidential
# ...
# 1/1 [==============================] - 0s 33ms/step
# label: parkinglot
# ...
# 1/1 [==============================] - 0s 35ms/step
# label: storagetanks
# ...
# 1/1 [==============================] - 0s 32ms/step
# label: overpass
# ...
# 1/1 [==============================] - 0s 32ms/step
# label: sparseresidential
# ...
# 1/1 [==============================] - 0s 33ms/step
# label: mediumresidential
# ...
# 1/1 [==============================] - 0s 32ms/step
# label: intersection
# ...
# 1/1 [==============================] - 0s 32ms/step
# ...
# ...
# 1/1 [==============================] - 0s 39ms/step
# label: forest
# ...
# 1/1 [==============================] - 0s 31ms/step
# label: golfcourse
# ...
# 1/1 [==============================] - 0s 33ms/step
# label: agricultural
# ...
